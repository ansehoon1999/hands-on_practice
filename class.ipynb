# %% [markdown]
# # 기존의 불편한 점

# %%
result = 0

def add(num):
    global result
    result += num
    return result

print(add(3))
print(add(4))
# Out:
# 3
# 7

# %% [markdown]
# 전역 변수를 각각 설정했지만 수백 만개의 더하기가 필요한 경우에도 계속 각각을 만들어야할까?

# %%
result1 = 0
result2 = 0

def add1(num):
    global result1
    result1 += num
    return result1

def add2(num):
    global result2
    result2 += num
    return result2

print(add1(3))
print(add1(4))
print(add2(3))
print(add2(7))
# Out:
# 3
# 7
# 3
# 10

# %% [markdown]
# # class

# %%
class Calculator :
  def __init__ (self) :
    self.result = 0

  def add(self, num) :
    self.result += num
    return self.result
  
cal1 = Calculator()
cal2 = Calculator()

print(cal1.add(3))
print(cal1.add(4))
print(cal2.add(3))
print(cal2.add(7))
# Out:
# 3
# 7
# 3
# 10

# %% [markdown]
# ![스크린샷 2021-07-09 오후 5.46.37.png](data:image/png;base64,...)

# %% [markdown]
# 과자 틀 = 클래스
# 과자 틀에 의해서 만들어진 과자 = 객체

# %%
class FourCal:
  def setdata(self, first, second):
    self.first = first
    self.second = second
  def add(self):
    result = self.first + self.second
    return result
  def mul(self):
    result = self.first * self.second
    return result
  def sub(self):
    result = self.first - self.second
    return result
  def div(self):
    result = self.first / self.second
    return result

# %%
a = FourCal() 
b = FourCal()
print(a.setdata(4, 2))
print(b.setdata(3, 8))
# Out:
# None
# None

# %% [markdown]
# # 생성자(Constructor)

# %%
a = FourCal()
a.add()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-93d8790fe05f> in <module>()
#       1 a = FourCal()
# ----> 2 a.add()
#
# <ipython-input-15-6cf56f5f636c> in add(self)
#       4     self.second = second
#       5   def add(self):
# ----> 6     result = self.first + self.second
#       7     return result
#       8   def mul(self):
#
# AttributeError: 'FourCal' object has no attribute 'first'

# %%
class FourCal:
  def __init__ (self, first, second) :
    self.first = first
    self.second =second 
  def setdata(self, first, second):
    self.first = first
    self.second = second
  def add(self):
    result = self.first + self.second
    return result
  def mul(self):
    result = self.first * self.second
    return result
  def sub(self):
    result = self.first - self.second
    return result
  def div(self):
    result = self.first / self.second
    return result

# %%
a = FourCal()
a.add()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-93d8790fe05f> in <module>()
# ----> 1 a = FourCal()
#       2 a.add()
#
# TypeError: __init__() missing 2 required positional arguments: 'first' and 'second'

# %%
a = FourCal(4, 2)
print(a.add())
# Out:
# 6
